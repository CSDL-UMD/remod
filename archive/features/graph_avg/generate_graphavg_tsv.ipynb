# %%
import pickle
import pandas as pd
import numpy as np

# %%
pickle_f = '../../../all_data/relation_extraction/data/graph_avg/relation_vec_avg_df.pkl'

df_init = pd.read_pickle(pickle_f)

# %%
df_init
# Out:
#              relation         1         2         3         4         5  \
# 0         institution -0.000143  0.000126 -0.000401 -0.000642 -0.001344
# 1         institution  0.000837 -0.000580 -0.003097  0.001433 -0.000470
# 2         institution  0.000681 -0.001756 -0.005622  0.001035  0.003469
# 3         institution  0.000856  0.000151 -0.000593 -0.000067  0.000367
# 4         institution -0.005964 -0.002292 -0.019709  0.007854 -0.017246
# ...               ...       ...       ...       ...       ...       ...
# 25743  place_of_death  0.001074  0.000660 -0.000566 -0.000029  0.000719
# 25744  place_of_death  0.000213 -0.000127  0.000057 -0.000233 -0.000051
# 25745  place_of_death  0.000060 -0.000546 -0.001136  0.000366 -0.000811
# 25746  place_of_death  0.000487  0.000211 -0.001257  0.001453  0.000989
# 25747  place_of_death  0.000045 -0.000577 -0.000021  0.000010  0.000101
#
#               6         7         8         9  ...       119       120  \
# ...

# %%
df_vecs = df_init.loc[:, df_init.columns != 'relation']
df_vecs
# Out:
#             1         2         3         4         5         6         7    \
# 0     -0.000143  0.000126 -0.000401 -0.000642 -0.001344 -0.000802 -0.000330
# 1      0.000837 -0.000580 -0.003097  0.001433 -0.000470  0.001877  0.001546
# 2      0.000681 -0.001756 -0.005622  0.001035  0.003469  0.002098 -0.003262
# 3      0.000856  0.000151 -0.000593 -0.000067  0.000367  0.000752  0.000415
# 4     -0.005964 -0.002292 -0.019709  0.007854 -0.017246  0.002508 -0.004847
# ...         ...       ...       ...       ...       ...       ...       ...
# 25743  0.001074  0.000660 -0.000566 -0.000029  0.000719  0.000766 -0.000151
# 25744  0.000213 -0.000127  0.000057 -0.000233 -0.000051  0.000207 -0.000447
# 25745  0.000060 -0.000546 -0.001136  0.000366 -0.000811  0.000561 -0.000318
# 25746  0.000487  0.000211 -0.001257  0.001453  0.000989  0.001036 -0.004220
# 25747  0.000045 -0.000577 -0.000021  0.000010  0.000101  0.000187  0.000808
#
# ...

# %%
df_meta = df_init.loc[:,df_init.columns == 'relation']
df_meta
# Out:
#              relation
# 0         institution
# 1         institution
# 2         institution
# 3         institution
# 4         institution
# ...               ...
# 25743  place_of_death
# 25744  place_of_death
# 25745  place_of_death
# 25746  place_of_death
# 25747  place_of_death
#
# [25748 rows x 1 columns]

# %%
with open('./avg_vecs.tsv', "w") as write_tsv:
    write_tsv.write(df_vecs.to_csv(sep='\t', index=False))

# %%
with open('./avg_vecs_meta.tsv', 'w') as write_tsv:
    write_tsv.write(df_meta.to_csv(sep='\t', index=False))
