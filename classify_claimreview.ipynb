# %% [markdown]
# # Classify Selected ClaimReview Claims

# %% [markdown]
# ### Imports

# %%
import os
import datetime
import h5py
import logging
import argparse
import pickle
import pandas as pd
import keras
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Input
from tensorflow.keras.layers import BatchNormalization, LayerNormalization
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn import metrics
from matplotlib import pyplot as plt
import seaborn as sns
from joblib import dump, load
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import config
from utils.file import directory_check

# %% [markdown]
# ### Functions

# %%
# Prediction int to string
def prediction_value(pred):
    value_dict = {'0': 'dob', '1': 'education', '2': 'institution', '3':'pob', '4':'pod'}
    index = None
    num = max(max(pred))
    for i,item in enumerate(pred[0]):
        if item == num:
            index = i
    return value_dict[str(index)]

# Adds prediction to dataframe
def predict_df(X):
    vec = X["Short_Path"]
    shape = vec.shape[0]
    vec = np.reshape(vec, (shape,1)).T
    prediction = prediction_value(MODEL.predict(vec))
    
    return prediction

# Adds prediction evaluation to dataframe
def predict_success(X):
    prediction = X['Prediction']
    actual = X['Relation']
    
    if prediction == actual:
        return "Yes"
    else:
        return "No"

# %% [markdown]
# ### Load trained model and dataframe of shortest paths

# %%
model_f = '/sp_model-dnn_wide-dnn_wide-cr-d256-wl50-nw200-win15-p2-q3-201119.h5'
MODEL = tf.keras.models.load_model(config.MODEL_DIR + model_f) 

sp_file = '/sp_df-cr-d256-wl50-nw200-win15-p2-q3-201118.pkl'

# %% [markdown]
# ### Modify Dataframe for Prediction task

# %%
df = pd.read_pickle(config.SP_DIR + sp_file)

df = df[df['Relation']=='cr'] # Remove all non-ClaimReview Claims

# Sort entries by UID
df['ID'] = df['UID'].apply(lambda x: x.split('_')[-1].split('r')[-1]).astype(int)
df = df.set_index('ID')
df = df.sort_index()
df['Relation']=df['UID'].apply(lambda x: x.split('_')[0])

# Add Two new Columns for Prediction analysis
df['Prediction'] = 'None'
df['Successful?'] = 'No'
df.head()
# Out:
#         UID       Subject         Object Relation Maj_Vote  \
# ID
# 1   pob_cr1    Penny Wong       Malaysia      pob      yes
# 2   pob_cr2  Barack Obama          Kenya      pob      yes
# 3   pob_cr3  Barack Obama  United States      pob      yes
# 4   pob_cr4    Fred Trump        Germany      pob      yes
# 5   dob_cr5  Barron Trump           2006      dob      yes
#
#                                            Short_Path Prediction Successful?
# ID
# 1   [-0.12060831, -0.004389023, 0.016019436, 0.095...       None          No
# 2   [-0.11935643, 0.0055734552, 0.032190174, -0.01...       None          No
# 3   [-0.022086723, 0.010196335, 0.033510454, 0.000...       None          No
# 4   [-0.08399602, -0.037151054, 0.017798765, 0.057...       None          No
# 5   [-0.14999631, -0.032707285, -0.07424754, 0.104...       None          No

# %% [markdown]
# ### Read in encoder and prep data

# %%
encoder_file = config.SP_SPLITS_DIR + '/class_encoder.npy'
encoder = LabelEncoder()
encoder.classes_ = np.load(encoder_file, allow_pickle=True)

# %%
X = df["Short_Path"].apply(pd.Series)

y = df[['Relation']]
y = encoder.transform(y)
y = to_categorical(y)
# Out:
# /data/mjsumpter/miniconda3/envs/re/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %% [markdown]
# ### Make Predictions

# %%
df["Prediction"] = df.apply(predict_df, axis=1)
df["Successful?"] = df.apply(predict_success, axis=1)
predictions = MODEL.predict(X)
print(f"AUC: {round(metrics.roc_auc_score(y, predictions), 3)}")

acc = len(df[df['Successful?']=='Yes'])/len(df) 
print(f"Accuracy: {round(acc*100,2)}%")
df
# Out:
# AUC: 0.958
# Accuracy: 71.43%
#                  UID                   Subject  \
# ID
# 1            pob_cr1                Penny Wong
# 2            pob_cr2              Barack Obama
# 3            pob_cr3              Barack Obama
# 4            pob_cr4                Fred Trump
# 5            dob_cr5              Barron Trump
# 6            dob_cr6          Isabelle Duterte
# 7      education_cr7          Tej Pratap Yadav
# 8      education_cr8              Smriti Irani
# 9      education_cr9             Melania Trump
# 10    education_cr10            Michelle Obama
# 11    education_cr11            Pravan Gordhan
# 12    education_cr12  Alexandria Ocasio-Cortez
# 13    education_cr13               Imee Marcos
# 14  institution_cr14               Imee Marcos
# 15  institution_cr15          Tej Pratap Yadav
# 16  institution_cr16            Patrick Murphy
# 17  institution_cr17            Vladimir Putin
# 18  institution_cr18             Marina Butina
# 19  institution_cr19               Imee Marcos
# 20  institution_cr20                David Hogg
# 21          pod_cr21          Manohar Parrikar
# 22          pod_cr22            Tucker Carlson
# 23          pod_cr23         Nasser Al Kharafi
# 24          pod_cr24               Amit Sharma
# 25          pod_cr25             Jason Statham
# 26          pod_cr26         Robert Downey Jr.
# 27  institution_cr27             Mahmoud Abbas
# 28  institution_cr28               Ali Kamenei
#
#                                      Object     Relation Maj_Vote  \
# ID
# 1                                  Malaysia          pob      yes
# 2                                     Kenya          pob      yes
# 3                             United States          pob      yes
# 4                                   Germany          pob      yes
# 5                                      2006          dob      yes
# 6                          January 26, 2002          dob      yes
# 7                          Doctorate Degree    education      yes
# 8                                 MA Degree    education      yes
# 9                         Bachelor's Degree    education      yes
# 10                             Juris Doctor    education      yes
# 11                                   Degree    education      yes
# 12                         Economics Degree    education      yes
# 13                        Bachelor's Degree    education      yes
# 14                     Princeton University  institution      yes
# 15                     Takshsila University  institution      yes
# 16                      University of Miami  institution      yes
# 17               Patrice Lumumba University  institution      yes
# 18                      American University  institution      yes
# 19            University of the Philippines  institution      yes
# 20  Redondo Shores Continuation High School  institution      yes
# 21                                      Goa          pod      yes
# 22                          Washington D.C.          pod      yes
# 23                                   Kuwait          pod      yes
# 24                                    Delhi          pod      yes
# 25                                 New York          pod      yes
# 26                                Hollywood          pod      yes
# 27               Patrice Lumumba University  institution      yes
# 28               Patrice Lumumba University  institution      yes
#
#                                            Short_Path   Prediction Successful?
# ID
# 1   [-0.12060831, -0.004389023, 0.016019436, 0.095...          dob          No
# 2   [-0.11935643, 0.0055734552, 0.032190174, -0.01...  institution          No
# 3   [-0.022086723, 0.010196335, 0.033510454, 0.000...          pob         Yes
# 4   [-0.08399602, -0.037151054, 0.017798765, 0.057...          pob         Yes
# 5   [-0.14999631, -0.032707285, -0.07424754, 0.104...          pob          No
# 6   [-0.04258087, -0.14339234, 0.0050823386, 0.008...          dob         Yes
# 7   [-0.09566146, -0.04633151, -0.0026847243, 0.02...    education         Yes
# 8   [-0.073904075, -0.0076472485, 0.050191842, 0.0...  institution          No
# 9   [-0.10019517, -0.05538463, -0.023950523, 0.043...  institution          No
# 10  [-0.07963335, 0.0015545988, 0.04472027, 0.0461...    education         Yes
# 11  [-0.056872778, -0.025289508, 0.07884932, 0.046...    education         Yes
# 12  [-0.09500959, -0.001853646, 0.004757661, 0.062...  institution          No
# 13  [-0.056798395, 0.014900852, 0.089383245, 0.039...    education         Yes
# 14  [-0.0549962, 0.025464775, 0.055563904, 0.03784...  institution         Yes
# 15  [-0.10572188, -0.050793696, 0.00036571862, 0.0...    education          No
# 16  [-0.08051448, -0.08235108, -0.12463131, 0.0750...  institution         Yes
# 17  [-0.1198068, -0.1268384, -0.07182188, -0.03225...  institution         Yes
# 18  [-0.015518223, -0.09944429, 0.050411142, 0.066...  institution         Yes
# 19  [-0.015078805, -0.08362012, 0.0044884505, -0.0...  institution         Yes
# 20  [-0.031023895, -0.06987886, 0.032975923, 0.031...  institution         Yes
# 21  [-0.057718426, -0.05839586, -0.0493096, 0.0290...          pod         Yes
# 22  [-0.070726745, 0.010831918, 0.01879863, 0.0026...          pod         Yes
# 23  [0.011382176, 0.03712737, -0.038807902, 0.0200...          pod         Yes
# 24  [-0.010342093, -0.10143781, 0.040919952, 0.022...  institution          No
# 25  [-0.082907505, -0.022500908, -0.02242381, -0.0...          pod         Yes
# 26  [0.0017659222, -0.010442543, -0.04193017, 0.06...          pod         Yes
# 27  [-0.11917672, -0.12843396, -0.068598576, -0.03...  institution         Yes
# 28  [-0.12323489, -0.12734397, -0.060544815, -0.03...  institution         Yes

# %% [markdown]
# ### Save Predictions

# %%
directory_check(config.CLAIM_DIR)
df.to_pickle(config.CLAIM_DF)
